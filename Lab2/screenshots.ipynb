# %% [markdown]
# ### Storage Account (ADLS Gen2)
# ![Storage Account](/Volumes/dbr_dev/radekgryciukk_bronze/screenshots/StorageAcc.png)

# %% [markdown]
# ![Storage Account](/Volumes/dbr_dev/radekgryciukk_bronze/screenshots/StorageAcc hierarchical namespace.png)

# %% [markdown]
# ![Storage Account](/Volumes/dbr_dev/radekgryciukk_bronze/screenshots/StorageAcc Networking.png)

# %% [markdown]
# ### Key Vault
# ![Key Vault](/Volumes/dbr_dev/radekgryciukk_bronze/screenshots/KeyVault.png)

# %% [markdown]
# ![Key Vault](/Volumes/dbr_dev/radekgryciukk_bronze/screenshots/KV RBAC.png)

# %% [markdown]
# ### Databricks workspace
# ![Databricks workspace](/Volumes/dbr_dev/radekgryciukk_bronze/screenshots/DB_workspace.png)

# %% [markdown]
# ![Databricks workspace](/Volumes/dbr_dev/radekgryciukk_bronze/screenshots/DB_workspace_networking.png)
